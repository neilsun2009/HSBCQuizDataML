# %% [markdown]
# # Product Analysis
#
# Use jupyter notebook to conduct interactive data analysis.
#
# Also output crucial files for data visualization on web.

# %%
import numpy as np
import pandas as pd
import json
import math
import os
from tqdm import tqdm
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup

# json encoder for numpy
class NpEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        if isinstance(obj, np.floating):
            return None if math.isnan(obj) else float(obj)
        if isinstance(obj, np.ndarray):
            return obj.tolist()
        return super(NpEncoder, self).default(obj)
    
# Define a function to remove HTML tags from a string
def remove_html_tags(text):
    soup = BeautifulSoup(text, "html.parser")
    stripped = soup.get_text(separator=" ")
    return stripped

COMMENT_SAMPLE_N = 10
PRODUCT_SAMPLE_N = 5

customer_csv_path = '../data/csv/aug_customers.csv'
product_csv_path = '../data/csv/aug_products.csv'
comment_csv_path = '../data/csv/aug_comments.csv'

output_base_dir = '../stats/product'

# %%
# parse selected comments to json form
# and join info from products & customers
def parse_joined_comments_to_json(selected_comment_df):
    comments = []
    for idx, comment_ds in selected_comment_df.iterrows():
        comment = {
            'summary': None if isinstance(comment_ds['summary'], float) and math.isnan(comment_ds['summary']) else comment_ds['summary'],
            'review': comment_ds['review'],
            'timestamp': comment_ds['timestamp'],
            'rating': comment_ds['overall'],
            'sentiment': comment_ds['sentiment'],
            'overall': comment_ds['sentimentWithRating'],
            'wordCount': comment_ds['wordCount'],
        }
        customer_ds = customer_df[customer_df['customerId']==comment_ds['customerId']].iloc[0]
        product_ds = product_df[product_df['asin']==comment_ds['asin']].iloc[0]
        comment['customer'] = {
            'customerId': customer_ds['customerId'],
            'name': customer_ds['name'],
            'cluster': customer_ds['cluster'],
        }
        comment['product'] = {
            'asin': product_ds['asin'],
            'title': product_ds['title'],
            'brand': None if isinstance(product_ds['brand'], float) and math.isnan(product_ds['brand']) else product_ds['brand'],
            # 'imageUrl': product_ds['imageUrl'],
            'imageUrl': None if isinstance(product_ds['imageUrl'], float) and math.isnan(product_ds['imageUrl']) else product_ds['imageUrl'],
            'price': product_ds['price'],
            'categories': product_ds['categories'].split(','),
            'avgRating': product_ds['avgOverall'],
            'avgSentiment': product_ds['avgSentiment'],
            'avgOverall': product_ds['avgSentimentWithRating'],
            'reviewCount': product_ds['reviewCount'],
        }
        comments.append(comment)
    return comments

# %% [markdown]
# ## Load Data

# %%
product_df = pd.read_csv(product_csv_path)
total_count = len(product_df)

print(f'Number of products: {total_count}')
# Out:
# /tmp/ipykernel_55801/201748605.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   product_df = pd.read_csv(product_csv_path)
# Number of products: 181839

# %%
product_df = product_df[product_df['reviewCount'] > 0]
total_count = len(product_df)

print(f'Number of products with comments: {total_count}')
# Out:
# Number of products with comments: 180424

# %%
comment_df = pd.read_csv(comment_csv_path)
comment_df.head()
# Out:
#    overall            customerId        asin  \
# 0      1.0  A00013803RVZPCZKTT9U  B003ZTNT2Y
# 1      5.0  A0001392IVCRENBEIEYS  6302409365
# 2      5.0  A0001598OL7FAN6XNMK9  B00BMRTPEM
# 3      4.0  A0001598OL7FAN6XNMK9  B00IV3FLO8
# 4      5.0  A0001598OL7FAN6XNMK9  B00OGL6S64
#
#                                              summary  \
# 0                                           One Star
# 1                         I'm so glad I watched this
# 2  its riveting. i have to keep myself controlled...
# 3                                         Four Stars
# 4  its riveting. i have to keep myself controlled...
#
#                                               review   timestamp  sentiment  \
# 0                                           Crap!!!!  1485129600    -1.0000
# 1    This made my night. I'm so glad I watched this.  1488240000     0.5000
# 2  its riveting. i have to keep myself controlled...  1478649600     0.2500
# 3     Great action. Good twists. It's sexy it's hot!  1475625600     0.4825
# 4  its riveting. i have to keep myself controlled...  1478649600     0.2500
#
#    sentimentWithRating  wordCount
# 0              1.00000          1
# 1              8.75000          9
# 2              8.12500         22
# 3              7.70625          8
# 4              8.12500         22

# %%
customer_df = pd.read_csv(customer_csv_path)

customer_df.head()
# Out:
#        customerId           name  cluster  distanceToCenter  vector2dX  \
# 0  A3478QRKQDOPQ2          jacki        2         13.761846   6.972486
# 1  A2VHSG6TZHU1OB          Ken P        3         33.170107  15.408235
# 2  A23EJWOW1TLENE  Reina Berumen        0          8.186462  -1.312076
# 3  A1KM9FNEJ8Q171        N Coyle        0         12.849782  -5.788060
# 4  A38LY2SSHVHRYB   Jodie Vesely        0         12.660837  -0.643088
#
#    vector2dY
# 0  13.825474
# 1  -2.924636
# 2   5.836580
# 3   5.276560
# 4  -1.748742

# %%
product_df.head()
# Out:
#               asin                                              title  \
# 51      0253030471                     Cuba: The Forgotten Revolution
# 44      0075723840  Direct Instruction Professional Development Vi...
# 5       000073991X               The Power of the Cross Joseph Prince
# 181791  B01HFFZNCW                          As We Speak - Lyric Video
# 181792  B01HFH0NI4            The X-Files: The Event Series [Blu-ray]
#
#                  brand                                        description  \
# 51                 NaN  <P>Cuba: The Forgotten Revolution tells the vi...
# 44                 NaN                           Set of Six VHS cassettes
# 5        Joseph Prince  Have failures in your life caused you to feel ...
# 181791  Greater Vision  1. Put Out The Fire 2. We Can't Tell It All 3....
# 181792  David Duchovny  Thirteen years after the original series run, ...
#
#                                                  imageUrl     rank  price  \
# 51                                                    NaN   170494  24.95
# 44      https://images-na.ssl-images-amazon.com/images...  1040896  -1.00
# 5                                                     NaN   444474  -1.00
# 181791                                                NaN   269649  13.98
# 181792                                                NaN   370140  -1.00
#
#                                                categories  avgOverall  \
# 51                                                 Movies         5.0
# 44                                                     TV         5.0
# 5        Genre for Featured Categories,Exercise & Fitness         5.0
# 181791  Genre for Featured Categories,Music Videos & C...         5.0
# 181792  Science Fiction & Fantasy,Science Fiction,Alie...         5.0
#
#         avgSentiment  avgSentimentWithRating  reviewCount
# 51          0.350000                8.375000            1
# 44          0.550000                8.875000            1
# 5           0.225000                8.062500            1
# 181791      0.262338                8.155844            1
# 181792      0.492312                8.730781            1

# %%
product_df.describe()
# Out:
#                price     avgOverall   avgSentiment  avgSentimentWithRating  \
# count  180424.000000  180424.000000  180424.000000           180424.000000
# mean       10.482098       4.055638       0.270196                7.231127
# std        21.633057       0.977952       0.201660                1.319454
# min        -1.000000       1.000000      -1.000000                1.000000
# 25%        -1.000000       3.636364       0.156517                6.621340
# 50%         5.980000       4.333333       0.269341                7.518625
# 75%        14.990000       4.833333       0.376019                8.102461
# max       999.990000       5.000000       1.000000               10.000000
#
#          reviewCount
# count  180424.000000
# mean       47.411026
# std       309.753167
# min         1.000000
# 25%         2.000000
# 50%         4.000000
# 75%        17.000000
# max     24088.000000

# %% [markdown]
# ## Product Comment Count

# %%
# sort by length
product_df.sort_values(by=['reviewCount'], inplace=True)

product_df.head()
# Out:
#               asin                                              title brand  \
# 68865   B000LE4JA2  Exploring Horizons A Rugged Beauty - North Van...   NaN
# 68868   B000LE872S  Exploring Horizons Caribbean Soul - Caye Caulk...   NaN
# 143535  B009XF3EOC  Bike-O-Vision Cycling Video- Eastern Sierra Hi...  none
# 143581  B009YDW5NO            GOSICK BLU-RAY BOX(4BLU-RAY+CD+BOOKLET)   NaN
# 143582  B009YEUSF0                   DAS B&ouml;se - Phantasm-box 1-4   NaN
#
#                                               description  \
# 68865   From the aerial view to the human perspective,...
# 68868   From the aerial view to the human perspective,...
# 143535  Splashes of fall color highlight dramatic moun...
# 143581                                Japanese Rare Items
# 143582  Quick Shipping !!! New And Sealed !!! This Dis...
#
#                                                  imageUrl    rank  price  \
# 68865                                                 NaN  832806  19.99
# 68868                                                 NaN  604668  19.99
# 143535                                                NaN  431908  22.95
# 143581  https://images-na.ssl-images-amazon.com/images...  807593  -1.00
# 143582  https://images-na.ssl-images-amazon.com/images...  427681  -1.00
#
#                                                categories  avgOverall  \
# 68865     Genre for Featured Categories,Special Interests         1.0
# 68868     Genre for Featured Categories,Special Interests         2.0
# 143535                                     Blu-ray,Movies         5.0
# 143581                                     Blu-ray,Movies         5.0
# 143582  Art House & International,By Original Language...         3.0
#
#         avgSentiment  avgSentimentWithRating  reviewCount
# 68865       0.250000                4.125000            1
# 68868      -0.051786                4.370536            1
# 143535      0.396429                8.491071            1
# 143581      0.051852                7.629630            1
# 143582      0.000000                5.500000            1

# %%
product_df.tail()
# Out:
#               asin                                     title          brand  \
# 178936  B01BHTSIOC             Doctor Thorne - Season 1 2015            NaN
# 145635  B00AQVMZKQ                  Downton Abbey - Series 4   Maggie Smith
# 81360   B000WGWQG8                                John Adams  Paul Giamatti
# 31289   B00006CXSS                    Band Of Brothers (DVD)   Damian Lewis
# 173750  B00YSG2ZPA  Band of Brothers(Elite SC/BD+DCExp12-21)        Various
#
#                                               description  \
# 178936  Tom Hollander (<em>Rev</em>, <em>A Poet In New...
# 145635  NOTICE: Polish Release, cover may contain Poli...
# 81360                                    John Adams (DVD)
# 31289   Based on the bestseller by Stephen E. Ambrose,...
# 173750                                          <![CDATA[
#
#                                                  imageUrl    rank  price  \
# 178936  https://images-na.ssl-images-amazon.com/images...  123323  14.88
# 145635  https://images-na.ssl-images-amazon.com/images...  165427  17.74
# 81360   https://images-na.ssl-images-amazon.com/images...   49694  38.66
# 31289   https://images-na.ssl-images-amazon.com/images...   14431  -1.00
# 173750  https://images-na.ssl-images-amazon.com/images...     503  25.16
#
#                                    categories  avgOverall  avgSentiment  \
# 178936  Genre for Featured Categories,Romance    4.423445      0.446030
# 145635                             Blu-ray,TV    4.829337      0.455143
# 81360                      HBO,All HBO Titles    4.686705      0.438693
# 31289                      HBO,All HBO Titles    4.913773      0.513329
# 173750                     HBO,All HBO Titles    4.913193      0.513080
#
#         avgSentimentWithRating  reviewCount
# 178936                8.038519        20508
# 145635                8.467196        20602
# 81360                 8.283437        23106
# 31289                 8.697096        24018
# 173750                8.695894        24088

# %%
product_review_count_stat = []
thresholds = [1, 10, 100, 1000, 10000]

for idx, thres in enumerate(thresholds):
    if idx < len(thresholds) - 1:
        cat = f'{thres} ~ {thresholds[idx+1]-1} comments'
        subset_df = product_df[product_df["reviewCount"].between(thres, thresholds[idx+1], inclusive='left')]
    else:
        cat = f'>= {thres} comments'
        subset_df = product_df[product_df["reviewCount"] >= thres]
    count = len(subset_df)
    print(f'{count} comments in category {cat}, accounts for {100*count/total_count:.2f}%')
    
    product_review_count_stat.append({
        'category': cat,
        'count': count,
    })
# Out:
# 118855 comments in category 1 ~ 9 comments, accounts for 65.88%
# 48412 comments in category 10 ~ 99 comments, accounts for 26.83%
# 11790 comments in category 100 ~ 999 comments, accounts for 6.53%
# 1341 comments in category 1000 ~ 9999 comments, accounts for 0.74%
# 26 comments in category >= 10000 comments, accounts for 0.01%

# %% [markdown]
# Another example of 80/20 rule: 65% of products only have less than 10 comments.

# %%
with open(os.path.join(output_base_dir, 'comment_count.json'), 'w') as f:
    json.dump(product_review_count_stat, f, cls=NpEncoder)

# %% [markdown]
# # Best Products
#
# Select products with at least 10 comments.

# %%
# select products with at least 20 comments
product_df = product_df[product_df['reviewCount'] >= 20]

print(f'{len(product_df)} products have at least 20 comments')
# Out:
# 41678 products have at least 20 comments

# %%
product_df = product_df.sort_values(by=['avgSentimentWithRating'], ascending=False)

# %%
product_df.head()
# Out:
#               asin                                              title  \
# 176284  B015S222SW               Wonderful World - Live In Maastricht
# 169748  B00S64UYOY       Passion Talk Series: The Complete Collection
# 164270  B00LHD6K62            The Notebook / The Time Traveler's Wife
# 36048   B0000A1QO4  Adventures In Odyssey: Fine Feathered Frenzy &...
# 152327  B00DPUB5LU                  Best of Collection: Family Affair
#
#                brand                                        description  \
# 176284           NaN  NTSC/Region 0. Andr's fans have been looking f...
# 169748  Louie Giglio  The all new PASSION TALK SERIES: THE COMPLETE ...
# 164270       Various                                          <![CDATA[
# 36048     Mike Joens  Dylan and Sal find themselves trapped in a wor...
# 152327   Brian Keith  From The Creator of My Three Sons Comes Anothe...
#
#                                                  imageUrl    rank   price  \
# 176284  https://images-na.ssl-images-amazon.com/images...   68332   19.38
# 169748                                                NaN   31928  199.95
# 164270  https://images-na.ssl-images-amazon.com/images...   58046    9.26
# 36048                                                 NaN  229180   -1.00
# 152327                                                NaN   90305    9.54
#
#                                                categories  avgOverall  \
# 176284               Musicals & Performing Arts,Classical    4.967742
# 169748  Genre for Featured Categories,Faith & Spiritua...    4.964286
# 164270                Genre for Featured Categories,Drama    4.904762
# 36048             Independently Distributed,Kids & Family    4.954545
# 152327        Genre for Featured Categories,Kids & Family    5.000000
#
#         avgSentiment  avgSentimentWithRating  reviewCount
# 176284      0.640273                9.068425           31
# 169748      0.615060                9.001937           28
# 164270      0.633446                8.988378           21
# 36048       0.602042                8.959650           22
# 152327      0.583028                8.957569           20

# %%
product_df.tail()
# Out:
#               asin                      title                 brand  \
# 21656   B00000IBQH  'N Sync, Never Enough VHS                   NaN
# 71533   B000N2HBIY        Diary of a Cannibal        Trevor Parsons
# 179310  B01C7RBFNE              Just Our Luck  Sarah Jayne Rothkopf
# 81949   B000WZALY8              Juarez Mexico          James Cahill
# 133175  B005VU53SS         Murder at Monogram           Gil Gilbert
#
#                                               description imageUrl    rank  \
# 21656                                               music      NaN  832207
# 71533   INSPIRED BY A REAL-LIFE CASE OF A WOMAN WHO MU...      NaN  315320
# 179310  After opening a mysterious fortune cookie, wit...      NaN  149387
# 81949   Since 1993 more than 400 girls have been kille...      NaN   52787
# 133175  In 1945 Monogram pictures is about to start pr...      NaN  516713
#
#         price                                         categories  avgOverall  \
# 21656    1.72  Genre for Featured Categories,Music Videos & C...    1.181818
# 71533   14.98  Studio Specials,Lionsgate Home Entertainment,A...    1.200000
# 179310  14.98                   Independently Distributed,Comedy    1.344615
# 81949    6.32   Genre for Featured Categories,Action & Adventure    1.095238
# 133175  24.95   Genre for Featured Categories,Action & Adventure    1.027027
#
#         avgSentiment  avgSentimentWithRating  reviewCount
# 21656      -0.129576                3.357878           22
# 71533      -0.225561                3.136098           35
# 179310     -0.305184                3.081655          325
# 81949      -0.260645                2.943626           21
# 133175     -0.246286                2.911311           37

# %%
best_products_stat = []

with tqdm(total=PRODUCT_SAMPLE_N) as pbar:
    for i in range(PRODUCT_SAMPLE_N):
        product = product_df.iloc[i]
        # choose longest reviews
        comments = comment_df[comment_df['asin'] == product['asin']]
        comments = comments.sort_values(by=['wordCount'], ascending=False)
        best_products_stat.append({
            'rank': i + 1,
            'samples': parse_joined_comments_to_json(comments.head(COMMENT_SAMPLE_N))
        })
        pbar.update(1)
# Out:
# 100%|██████████| 5/5 [02:23<00:00, 28.73s/it]

# %%
with open(os.path.join(output_base_dir, 'best_products.json'), 'w') as f:
    json.dump(best_products_stat, f, cls=NpEncoder)

# %% [markdown]
# ## Worst Products

# %%
product_df = product_df.sort_values(by=['avgSentimentWithRating'], ascending=True)

# %%
product_df.head()
# Out:
#               asin                      title                 brand  \
# 133175  B005VU53SS         Murder at Monogram           Gil Gilbert
# 81949   B000WZALY8              Juarez Mexico          James Cahill
# 179310  B01C7RBFNE              Just Our Luck  Sarah Jayne Rothkopf
# 71533   B000N2HBIY        Diary of a Cannibal        Trevor Parsons
# 21656   B00000IBQH  'N Sync, Never Enough VHS                   NaN
#
#                                               description imageUrl    rank  \
# 133175  In 1945 Monogram pictures is about to start pr...      NaN  516713
# 81949   Since 1993 more than 400 girls have been kille...      NaN   52787
# 179310  After opening a mysterious fortune cookie, wit...      NaN  149387
# 71533   INSPIRED BY A REAL-LIFE CASE OF A WOMAN WHO MU...      NaN  315320
# 21656                                               music      NaN  832207
#
#         price                                         categories  avgOverall  \
# 133175  24.95   Genre for Featured Categories,Action & Adventure    1.027027
# 81949    6.32   Genre for Featured Categories,Action & Adventure    1.095238
# 179310  14.98                   Independently Distributed,Comedy    1.344615
# 71533   14.98  Studio Specials,Lionsgate Home Entertainment,A...    1.200000
# 21656    1.72  Genre for Featured Categories,Music Videos & C...    1.181818
#
#         avgSentiment  avgSentimentWithRating  reviewCount
# 133175     -0.246286                2.911311           37
# 81949      -0.260645                2.943626           21
# 179310     -0.305184                3.081655          325
# 71533      -0.225561                3.136098           35
# 21656      -0.129576                3.357878           22

# %%
worst_products_stat = []

with tqdm(total=PRODUCT_SAMPLE_N) as pbar:
    for i in range(PRODUCT_SAMPLE_N):
        product = product_df.iloc[i]
        comments = comment_df[comment_df['asin'] == product['asin']]
        comments = comments.sort_values(by=['wordCount'], ascending=False)
        worst_products_stat.append({
            'rank': i + 1,
            'samples': parse_joined_comments_to_json(comments.head(COMMENT_SAMPLE_N))
        })
        pbar.update(1)
# Out:
# 100%|██████████| 5/5 [02:23<00:00, 28.76s/it]

# %%
with open(os.path.join(output_base_dir, 'worst_products.json'), 'w') as f:
    json.dump(worst_products_stat, f, cls=NpEncoder)
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
